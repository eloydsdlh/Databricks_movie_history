-- %%
CREATE SCHEMA IF NOT EXISTS movie_silver
MANAGED LOCATION "abfss://silver@moviehistory4.dfs.core.windows.net/"
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
DESCRIBE SCHEMA EXTENDED movie_silver
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database_description_item</th><th>database_description_value</th></tr></thead><tbody><tr><td>Catalog Name</td><td>databricks_course_ws_7405612138617619</td></tr><tr><td>Namespace Name</td><td>movie_silver</td></tr><tr><td>Comment</td><td></td></tr><tr><td>Location</td><td>abfss://silver@moviehistory4.dfs.core.windows.net/__unitystorage/schemas/ffe2bf3a-35dc-4d68-9185-2c5a4bc0a7db</td></tr><tr><td>Owner</td><td>eloydesande@gmail.com</td></tr><tr><td>RootLocation</td><td>abfss://silver@moviehistory4.dfs.core.windows.net/</td></tr><tr><td>Properties</td><td>((unity.catalog.managed.iceberg.defaults.delta.feature.catalogManaged,supported))</td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_eastus)</td></tr></tbody></table></div>
