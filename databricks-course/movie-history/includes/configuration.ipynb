# %%
bronze_folder_path = "abfss://bronze@moviehistory4.dfs.core.windows.net"
silver_folder_path = "abfss://silver@moviehistory4.dfs.core.windows.net"
gold_folder_path = "abfss://gold@moviehistory4.dfs.core.windows.net"
