-- %% [markdown]
-- # Eliminar y volver a crear todas las bases de datos

-- %%
DROP DATABASE IF EXISTS movie_silver CASCADE;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
CREATE SCHEMA IF NOT EXISTS movie_silver
MANAGED LOCATION "abfss://silver@moviehistory4.dfs.core.windows.net"
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
DROP DATABASE IF EXISTS movie_gold CASCADE;

-- %%
CREATE SCHEMA IF NOT EXISTS movie_gold
MANAGED LOCATION "abfss://gold@moviehistory4.dfs.core.windows.net"
