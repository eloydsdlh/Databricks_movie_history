# %% [markdown]
# ## Configurar accesso Azure Data Lake Storage Gen2
#
# 1. Crear el objeto `External Location` llamado `external_location_bronze_mov_his`
# 2. Crear el objeto `External Location` llamado `external_location_silver_mov_his`
# 3. Crear el objeto `External Location` llamado `external_location_gold_mov_his`
# 4. Validar acceso a los objetos `External Locations` creados

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS external_location_bronze_mov_his
    URL 'abfss://bronze@moviehistory4.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL storage_credential_movie_history)
    COMMENT 'External Location for the bronze data lakehouse'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS external_location_silver_mov_his
    URL 'abfss://silver@moviehistory4.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL storage_credential_movie_history)
    COMMENT 'External Location for the silver data lakehouse'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS external_location_gold_mov_his
    URL 'abfss://gold@moviehistory4.dfs.core.windows.net'
    WITH (STORAGE CREDENTIAL storage_credential_movie_history)
    COMMENT 'External Location for the gold data lakehouse'

# %% [markdown]
# Validamos el acceso

# %%
dbutils.fs.ls("abfss://bronze@moviehistory4.dfs.core.windows.net/")
# Out:
# [FileInfo(path='abfss://bronze@moviehistory4.dfs.core.windows.net/country.json', name='country.json', size=6014, modificationTime=1788887031000),
#  FileInfo(path='abfss://bronze@moviehistory4.dfs.core.windows.net/genre.csv', name='genre.csv', size=282, modificationTime=1788887030000),
#  FileInfo(path='abfss://bronze@moviehistory4.dfs.core.windows.net/language.csv', name='language.csv', size=1743, modificationTime=1788887031000),
#  FileInfo(path='abfss://bronze@moviehistory4.dfs.core.windows.net/language_role.json', name='language_role.json', size=114, modificationTime=1788887031000),
#  FileInfo(path='abfss://bronze@moviehistory4.dfs.core.windows.net/movie.csv', name='movie.csv', size=2107979, modificationTime=1788887030000),
#  FileInfo(path='abfss://bronze@moviehistory4.dfs.core.windows.net/movie_cast.json', name='movie_cast.json', size=6517381, modificationTime=1788887031000),
# ...

# %%
dbutils.fs.ls("abfss://silver@moviehistory4.dfs.core.windows.net/")
# Out:
# []

# %%
dbutils.fs.ls("abfss://gold@moviehistory4.dfs.core.windows.net/")
# Out:
# []
