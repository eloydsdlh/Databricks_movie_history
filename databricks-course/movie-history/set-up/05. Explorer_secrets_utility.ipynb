# %% [markdown]
# # Explorar las capacidades de la utilidad `dbutils.secrets`

# %%
dbutils.secrets.help()

# %%
dbutils.secrets.listScopes()
# Out:
# [SecretScope(name='movie-history-secret-scope')]

# %%
dbutils.secrets.list(scope = "movie-history-secret-scope")
# Out:
# [SecretMetadata(key='movie-access-key'),
#  SecretMetadata(key='movie-client-id'),
#  SecretMetadata(key='movie-client-secret'),
#  SecretMetadata(key='movie-tenant-id'),
#  SecretMetadata(key='movie-token-sas')]

# %%
# Obtener el secreto

dbutils.secrets.get(scope = "movie-history-secret-scope", key = "movie-access-key")
# Out:
# '[REDACTED]'
