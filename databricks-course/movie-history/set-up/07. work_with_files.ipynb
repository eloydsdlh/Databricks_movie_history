# %% [markdown]
# # Trabajar con Archivos (estilo URI y POSIX)
#
# 1. Mostrar los directorios del directorio raíz DBFS
# 2. Mostrar el contenido de un directorio dentro del directorio raíz DBFS
# 3. Mostrar el contenido del Sistema de Archivos Local
# 4. Interactuar con el "Explorador de Archivos DBFS"
# 5. Leer datos de ADLS mediante el estilo URI

# %%
# %fs

ls dbfs:/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/</td><td>Volumes/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/Workspace/</td><td>Workspace/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks/</td><td>databricks/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
dbutils.fs.ls("/")
# Out:
# [FileInfo(path='dbfs:/Volumes/', name='Volumes/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/Workspace/', name='Workspace/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks/', name='databricks/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0)]

# %%
# %fs
ls dbfs:/databricks-datasets
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/COVID/</td><td>COVID/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/README.md</td><td>README.md</td><td>976</td><td>1532502324000</td></tr><tr><td>dbfs:/databricks-datasets/Rdatasets/</td><td>Rdatasets/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/SPARK_README.md</td><td>SPARK_README.md</td><td>3359</td><td>1455505834000</td></tr><tr><td>dbfs:/databricks-datasets/adult/</td><td>adult/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/airlines/</td><td>airlines/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/amazon/</td><td>amazon/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/asa/</td><td>asa/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/atlas_higgs/</td><td>atlas_higgs/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/bikeSharing/</td><td>bikeSharing/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/cctvVideos/</td><td>cctvVideos/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/credit-card-fraud/</td><td>credit-card-fraud/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/cs100/</td><td>cs100/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/cs110x/</td><td>cs110x/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/cs190/</td><td>cs190/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/data.gov/</td><td>data.gov/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/definitive-guide/</td><td>definitive-guide/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/delta-sharing/</td><td>delta-sharing/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/flights/</td><td>flights/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/flower_photos/</td><td>flower_photos/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/flowers/</td><td>flowers/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/genomics/</td><td>genomics/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/hail/</td><td>hail/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/identifying-campaign-effectiveness/</td><td>identifying-campaign-effectiveness/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/inventory-reports/</td><td>inventory-reports/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/iot/</td><td>iot/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/iot-stream/</td><td>iot-stream/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark/</td><td>learning-spark/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/learning-spark-v2/</td><td>learning-spark-v2/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/lending-club-loan-stats/</td><td>lending-club-loan-stats/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/med-images/</td><td>med-images/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/media/</td><td>media/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/mnist-digits/</td><td>mnist-digits/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/news20.binary/</td><td>news20.binary/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/</td><td>nyctaxi/</td><td>0</td><td>1788885516959</td></tr><tr><td>dbfs:/databrick ...

# %%
dbutils.fs.ls("dbfs:/databricks-datasets")
# Out:
# [FileInfo(path='dbfs:/databricks-datasets/COVID/', name='COVID/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/README.md', name='README.md', size=976, modificationTime=1532502324000),
#  FileInfo(path='dbfs:/databricks-datasets/Rdatasets/', name='Rdatasets/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/SPARK_README.md', name='SPARK_README.md', size=3359, modificationTime=1455505834000),
#  FileInfo(path='dbfs:/databricks-datasets/adult/', name='adult/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/airlines/', name='airlines/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/amazon/', name='amazon/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/asa/', name='asa/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/atlas_higgs/', name='atlas_higgs/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/bikeSharing/', name='bikeSharing/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/cctvVideos/', name='cctvVideos/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/credit-card-fraud/', name='credit-card-fraud/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/cs100/', name='cs100/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/cs110x/', name='cs110x/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/cs190/', name='cs190/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/data.gov/', name='data.gov/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/definitive-guide/', name='definitive-guide/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/delta-sharing/', name='delta-sharing/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/flights/', name='flights/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/flower_photos/', name='flower_photos/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/flowers/', name='flowers/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/genomics/', name='genomics/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/hail/', name='hail/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/identifying-campaign-effectiveness/', name='identifying-campaign-effectiveness/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/inventory-reports/', name='inventory-reports/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/iot/', name='iot/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/iot-stream/', name='iot-stream/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/learning-spark/', name='learning-spark/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/learning-spark-v2/', name='learning-spark-v2/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/lending-club-loan-stats/', name='lending-club-loan-stats/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/med-images/', name='med-images/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/media/', name='media/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/mnist-digits/', name='mnist-digits/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/news20.binary/', name='news20.binary/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi/', name='nyctaxi/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi-with-zipcodes/', name='nyctaxi-with-zipcodes/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/online_retail/', name='online_retail/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/overlap-join/', name='overlap-join/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/power-plant/', name='power-plant/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/', name='retail-org/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/rwe/', name='rwe/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/sai-summit-2019-sf/', name='sai-summit-2019-sf/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/sample_logs/', name='sample_logs/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/samples/', name='samples/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/sfo_customer_survey/', name='sfo_customer_survey/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/sms_spam_collection/', name='sms_spam_collection/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/songs/', name='songs/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/structured-streaming/', name='structured-streaming/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/timeseries/', name='timeseries/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/tpch/', name='tpch/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/travel_recommendations_realtime/', name='travel_recommendations_realtime/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/warmup/', name='warmup/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/weather/', name='weather/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/wiki/', name='wiki/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/wikipedia-datasets/', name='wikipedia-datasets/', size=0, modificationTime=1788885454272),
#  FileInfo(path='dbfs:/databricks-datasets/wine-quality/', name='wine-quality/', size=0, modificationTime=1788885454272)]

# %%
# %fs
ls file:/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>file:/opt/</td><td>opt/</td><td>4096</td><td>1788885125853</td></tr><tr><td>file:/BUILD.bazel</td><td>BUILD.bazel</td><td>228</td><td>1788885059577</td></tr><tr><td>file:/sys/</td><td>sys/</td><td>0</td><td>1788885141405</td></tr><tr><td>file:/root/</td><td>root/</td><td>4096</td><td>1788885452730</td></tr><tr><td>file:/boot/</td><td>boot/</td><td>4096</td><td>1788885129307</td></tr><tr><td>file:/var/</td><td>var/</td><td>4096</td><td>1788885141982</td></tr><tr><td>file:/tmp/</td><td>tmp/</td><td>4096</td><td>1788885419871</td></tr><tr><td>file:/home/</td><td>home/</td><td>4096</td><td>1788885129634</td></tr><tr><td>file:/mnt/</td><td>mnt/</td><td>4096</td><td>1788885144319</td></tr><tr><td>file:/media/</td><td>media/</td><td>4096</td><td>1788885129634</td></tr><tr><td>file:/dev/</td><td>dev/</td><td>560</td><td>1788885141701</td></tr><tr><td>file:/lib.usr-is-merged/</td><td>lib.usr-is-merged/</td><td>4096</td><td>1788885126202</td></tr><tr><td>file:/proc/</td><td>proc/</td><td>0</td><td>1788885141405</td></tr><tr><td>file:/databricks/</td><td>databricks/</td><td>4096</td><td>1788885400096</td></tr><tr><td>file:/run/</td><td>run/</td><td>380</td><td>1788885256092</td></tr><tr><td>file:/bin.usr-is-merged/</td><td>bin.usr-is-merged/</td><td>4096</td><td>1788885126052</td></tr><tr><td>file:/etc/</td><td>etc/</td><td>4096</td><td>1788885141982</td></tr><tr><td>file:/srv/</td><td>srv/</td><td>4096</td><td>1788885129635</td></tr><tr><td>file:/lib/</td><td>lib/</td><td>4096</td><td>1788885129676</td></tr><tr><td>file:/bin/</td><td>bin/</td><td>36864</td><td>1788885129678</td></tr><tr><td>file:/sbin/</td><td>sbin/</td><td>12288</td><td>1788885129751</td></tr><tr><td>file:/sbin.usr-is-merged/</td><td>sbin.usr-is-merged/</td><td>4096</td><td>1788885126205</td></tr><tr><td>file:/usr/</td><td>usr/</td><td>4096</td><td>1788885129669</td></tr><tr><td>file:/lib64/</td><td>lib64/</td><td>4096</td><td>1788885091607</td></tr><tr><td>file:/Volumes/</td><td>Volumes/</td><td>4096</td><td>1788885159483</td></tr><tr><td>file:/ttyd/</td><td>ttyd/</td><td>4096</td><td>1788885254064</td></tr><tr><td>file:/local_disk0/</td><td>local_disk0/</td><td>4096</td><td>1788885254525</td></tr><tr><td>file:/Workspace/</td><td>Workspace/</td><td>4096</td><td>1788885159192</td></tr><tr><td>file:/dbfs/</td><td>dbfs/</td><td>4096</td><td>1788885159759</td></tr></tbody></table></div>

# %%
dbutils.fs.ls("/FileStore")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperationException             Traceback (most recent call last)
# File <command-6938556391600047>, line 1
# ----> 1 dbutils.fs.ls("/FileStore")
#
# File /databricks/python_shell/lib/dbruntime/dbutils.py:156, in prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     153 from py4j.protocol import Py4JJavaError
#     155 try:
# --> 156     return f(*args, **kwargs)
#     157 except Py4JJavaError as e:
#     159     class ExecutionError(Exception):
#
# File /databricks/python_shell/lib/dbruntime/dbutils.py:640, in DBUtils.FSHandler.ls(self, path)
#     636 @prettify_exception_message
#     637 def ls(self, path):
#     638     self.check_types([(path, string_types)])
#     639     return self.create_list_from_jschema(
# --> 640         self.print_return(self.fsutils.ls(path)), FileInfo.create_from_jschema)
#
# File /databricks/spark/python/lib/py4j-0.10.9.9-src.zip/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File /databricks/spark/python/pyspark/errors/exceptions/captured.py:310, in capture_sql_exception.<locals>.deco(*a, **kw)
#     306 converted = convert_exception(e.java_exception)
#     307 if not isinstance(converted, UnknownException):
#     308     # Hide where the exception came from that shows a non-Pythonic
#     309     # JVM exception message.
# --> 310     raise converted from None
#     311 else:
#     312     raise
#
# UnsupportedOperationException: Public DBFS root is disabled. Access is denied on path: /FileStore

# %%
dbutils.fs.ls("abfss://demo@moviehistory4.dfs.core.windows.net/")
# Out:
# [FileInfo(path='abfss://demo@moviehistory4.dfs.core.windows.net/movie.csv', name='movie.csv', size=2107979, modificationTime=1788635568000)]
